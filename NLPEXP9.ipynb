# %% [markdown]
# <a href="https://colab.research.google.com/github/teju123540/Natural-Language-Processing-Lab/blob/main/NLPEXP9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import urllib
import bs4 as bs
import re
# !pip install beautifulsoup4
# !pip install lxml
from bs4 import BeautifulSoup
nltk.download('punkt_tab')
# Out:
# ...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 56.0 MB/s eta 0:00:00
# ...

# %%
from gensim.models import Word2Vec

# %%
import requests
url = "https://en.wikipedia.org/wiki/Climate_change"
headers = {
    "User-Agent": "Mozilla/5.0"
}
response = requests.get(url, headers=headers)
source = response.text

# %%
soup = bs.BeautifulSoup(source, 'lxml')

# %%
text = ""
for paragraph in soup.find_all('p'):
    text += paragraph.text

# %%
text = re.sub(r'\[[0-9]*\]',' ',text)
text = re.sub(r'\s+',' ',text)
text = text.lower()
text = re.sub(r'\d',' ',text)

# %%
sentences = nltk.sent_tokenize(text)

# %%
sentences = [nltk.word_tokenize(sentence) for sentence in sentences]

# %%
sentences
# Out:
# [['present-day',
#   'climate',
#   'change',
#   'includes',
#   'both',
#   'global',
#   'warming—the',
#   'ongoing',
#   'increase',
#   'in',
#   'global',
#   'average',
#   'temperature—and',
#   'its',
#   'wider',
#   'effects',
#   'on',
#   'earth',
#   "'s",
#   'climate',
#   'system',
#   '.'],
#  ['climate',
#   'change',
#   'in',
#   'a',
#   'broader',
#   'sense',
#   'also',
#   'includes',
#   'previous',
#   'long-term',
#   'changes',
#   'to',
#   'earth',
#   "'s",
#   'climate',
#   '.'],
#  ['the',
#   'modern-day',
#   'rise',
#   'in',
#   'global',
#   'temperatures',
#   'is',
#   'driven',
#   'by',
#   'human',
#   'activities',
#   ',',
#   'especially',
#   'fossil',
#   'fuel',
#   '(',
#   'coal',
#   ',',
#   'oil',
#   'and',
#   'natural',
#   'gas',
#   ')',
#   'burning',
#   'since',
#   'the',
#   'industrial',
#   'revolution',
#   '.'],
#  ['fossil',
#   'fuel',
#   'use',
#   ',',
#   'deforestation',
#   ',',
#   'and',
#   'some',
# ...

# %%
model = Word2Vec(sentences,vector_size=100,min_count=1)
words = model.wv.index_to_key

# %%
print(words)
# Out:
# ['.', 'the', ',', 'and', 'of', 'to', 'in', 'climate', 'is', 'a', 'change', 'warming', 'as', 'for', 'that', 'by', 'are', 'global', 'have', 'emissions', 'from', 'more', 'be', 'on', 'can', '%', '°c', 'has', 'it', 'co', 'energy', 'with', 'carbon', 'greenhouse', 'also', ')', '(', 'or', "'s", 'this', 'countries', 'which', 'heat', 'been', 'such', 'was', 'would', 'atmosphere', 'gases', 'earth', 'these', 'temperature', 'at', 'than', '``', 'not', 'land', 'an', 'increase', 'over', "''", 'changes', 'but', 'impacts', 'increased', 'other', 'ice', 'use', 'gas', 'years', 'surface', 'there', 'people', 'fossil', 'models', 'under', 'sea', 'some', 'their', 'may', 'about', 'will', 'levels', 'since', 'they', 'less', 'between', 'were', 'ocean', 'while', 'reduce', 'air', 'level', 'reducing', 'could', '–', 'agreement', 'world', 'if', 'human', 'rise', 'into', 'effect', 'most', 'adaptation', 'ecosystems', 'sunlight', 'natural', 'its', 'due', 'regions', 'around', 'only', 'used', 's', 'like', 'century', 'water',
# ...

# %%
vector = model.wv['climate']

# %%
similar = model.wv.most_similar('climate')

# %%
similar
# Out:
# [(',', 0.9993810057640076),
#  ('and', 0.999337375164032),
#  ('of', 0.9992653727531433),
#  ('to', 0.9992448687553406),
#  ('in', 0.999225378036499),
#  ('the', 0.9992221593856812),
#  ('are', 0.9991397261619568),
#  ('.', 0.9990402460098267),
#  ('for', 0.9990370869636536),
#  ('by', 0.9989807605743408)]

# %%
vector = model.wv['climate']

# %%
similar = model.wv.most_similar('global')

# %%
similar
# Out:
# [('and', 0.9988375902175903),
#  ('the', 0.9988332986831665),
#  (',', 0.9988030195236206),
#  ('to', 0.998780369758606),
#  ('that', 0.9987140893936157),
#  ('of', 0.9987133741378784),
#  ('for', 0.9986636638641357),
#  ('climate', 0.9985873699188232),
#  ('in', 0.9985147714614868),
#  ('is', 0.9984883069992065)]
