# %% [markdown]
# <a href="https://colab.research.google.com/github/teju123540/Natural-Language-Processing-Lab/blob/main/NLP_EXP5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TOKENIZATION

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
para = """Bluetooth is a wireless technology used to connect devices over short distances without cables.
It allows easy data transfer, audio streaming, and device control using radio waves.
Bluetooth is energy-efficient and widely used in phones, headphones, and smart devices."""

# %%
sentence = nltk.sent_tokenize(para)

# %%
sentence
# Out:
# ['Bluetooth is a wireless technology used to connect devices over short distances without cables.',
#  'It allows easy data transfer, audio streaming, and device control using radio waves.',
#  'Bluetooth is energy-efficient and widely used in phones, headphones, and smart devices.']

# %% [markdown]
# STEMMER

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
for i in range(len(sentence)):
  words = nltk.word_tokenize(sentence[i])
  words = [stemmer.stem(word) for word in words]
  sentence[i] = ' '.join(words)

# %% [markdown]
# LEMMETISATION

# %%
from nltk.stem import WordNetLemmatizer

# %%
para1 = """Bluetooth is a wireless technology used to connect devices over short distances without cables.
It allows easy data transfer, audio streaming, and device control using radio waves.
Bluetooth is energy-efficient and widely used in phones, headphones, and smart devices."""

# %%
sentence1 = nltk.sent_tokenize(para1)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
lemmatizer = WordNetLemmatizer

# %%
for i in range(len(sentence1)):
  words = nltk.word_tokenize(sentence1[i])
  newwords = [lemmatizer.lemmatize(word) for word in words]
  sentence1[i] = ' '.join(newwords)

# %%
sentence1
# Out:
# ['Bluetooth is a wireless technology used to connect device over short distance without cable .',
#  'It allows easy data transfer , audio streaming , and device control using radio wave .',
#  'Bluetooth is energy-efficient and widely used in phone , headphone , and smart device .']

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
para3 = """Bluetooth is a wireless technology used to connect devices over short distances without cables.
It allows easy data transfer, audio streaming, and device control using radio waves.
Bluetooth is energy-efficient and widely used in phones, headphones, and smart devices."""

# %%
word = nltk.word_tokenize(para3)

# %%
tag_word = nltk.pos_tag(word)

# %%
tag_word
# Out:
# [('Bluetooth', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('wireless', 'JJ'),
#  ('technology', 'NN'),
#  ('used', 'VBN'),
#  ('to', 'TO'),
#  ('connect', 'VB'),
#  ('devices', 'NNS'),
#  ('over', 'IN'),
#  ('short', 'JJ'),
#  ('distances', 'NNS'),
#  ('without', 'IN'),
#  ('cables', 'NNS'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('allows', 'VBZ'),
#  ('easy', 'JJ'),
#  ('data', 'NNS'),
#  ('transfer', 'NN'),
#  (',', ','),
#  ('audio', 'JJ'),
#  ('streaming', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('device', 'NN'),
#  ('control', 'NN'),
#  ('using', 'VBG'),
#  ('radio', 'NN'),
#  ('waves', 'NNS'),
#  ('.', '.'),
#  ('Bluetooth', 'NNP'),
#  ('is', 'VBZ'),
#  ('energy-efficient', 'JJ'),
#  ('and', 'CC'),
#  ('widely', 'RB'),
#  ('used', 'VBN'),
#  ('in', 'IN'),
#  ('phones', 'NNS'),
#  (',', ','),
#  ('headphones', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('smart', 'JJ'),
#  ('devices', 'NNS'),
#  ('.', '.')]

# %%
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
import nltk
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# True

# %%
named_Ent = nltk.ne_chunk(tag_word)

# %%
# !pip install svgling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 4.6 MB/s eta 0:00:00
# ...

# %%
named_Ent
# Out:
# Tree('S', [Tree('GPE', [('Bluetooth', 'NNP')]), ('is', 'VBZ'), ('a', 'DT'), ('wireless', 'JJ'), ('technology', 'NN'), ('used', 'VBN'), ('to', 'TO'), ('connect', 'VB'), ('devices', 'NNS'), ('over', 'IN'), ('short', 'JJ'), ('distances', 'NNS'), ('without', 'IN'), ('cables', 'NNS'), ('.', '.'), ('It', 'PRP'), ('allows', 'VBZ'), ('easy', 'JJ'), ('data', 'NNS'), ('transfer', 'NN'), (',', ','), ('audio', 'JJ'), ('streaming', 'NN'), (',', ','), ('and', 'CC'), ('device', 'NN'), ('control', 'NN'), ('using', 'VBG'), ('radio', 'NN'), ('waves', 'NNS'), ('.', '.'), Tree('PERSON', [('Bluetooth', 'NNP')]), ('is', 'VBZ'), ('energy-efficient', 'JJ'), ('and', 'CC'), ('widely', 'RB'), ('used', 'VBN'), ('in', 'IN'), ('phones', 'NNS'), (',', ','), ('headphones', 'NNS'), (',', ','), ('and', 'CC'), ('smart', 'JJ'), ('devices', 'NNS'), ('.', '.')])
